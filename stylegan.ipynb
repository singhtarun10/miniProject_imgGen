# %%
! git clone https://github.com/NVlabs/stylegan3.git
# Out:
# Cloning into 'stylegan3'...

# %%
# %cd T:\pro\stylegan3
# Out:
# T:\pro\stylegan3

# %%
# %ls
# Out:
#  Volume in drive T is t_10
#  Volume Serial Number is 62E3-AA3C
#
#  Directory of T:\pro\stylegan3
#
# 28-03-2024  00:41    <DIR>          .
# 28-03-2024  00:41    <DIR>          ..
# 28-03-2024  00:41    <DIR>          .github
# 28-03-2024  00:41            12,969 avg_spectra.py
# 28-03-2024  00:41             8,302 calc_metrics.py
# 28-03-2024  00:41            18,581 dataset_tool.py
# 28-03-2024  00:41    <DIR>          dnnlib
# 28-03-2024  00:41               736 Dockerfile
# 28-03-2024  00:41    <DIR>          docs
# 28-03-2024  00:41               417 environment.yml
# 28-03-2024  00:41             5,880 gen_images.py
# 28-03-2024  00:41             7,463 gen_video.py
# 28-03-2024  00:41    <DIR>          gui_utils
# 28-03-2024  00:41            16,884 legacy.py
# 28-03-2024  00:41             4,484 LICENSE.txt
# 28-03-2024  00:41    <DIR>          metrics
# 28-03-2024  00:41            21,454 README.md
# 28-03-2024  00:41    <DIR>          torch_utils
# ...

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...

# %%
pip install click requests tqdm pyspng ninja imageio-ffmpeg==0.4.3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python  "T:\\pro\\stylegan3\\dataset_tool.py" --source="T:\\pro\\img" --dest="T:\\pro\\tfrecords" --resolution=256x256
# Out:
# ...
# 100%|██████████| 8842/8842 [00:42<00:00, 206.13it/s]

# %%
# %env CUDA_LAUNCH_BLOCKING=1
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
#it set the environment variable to 1
# %env TORCH_USE_CUDA_DSA=1
import os

# Set the environment variable
os.environ['TORCH_USE_CUDA_DSA'] = '1'


# Set the environment variable
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'
# Out:
# env: CUDA_LAUNCH_BLOCKING=1
# env: TORCH_USE_CUDA_DSA=1

# %%
import torch
import gc

# Clear the cache from PyTorch
torch.cuda.empty_cache()

# Use the garbage collector to release unreferenced memory
gc.collect()
# Out:
# 0

# %%
# !python  "T:\\pro\\stylegan3\\train.py" --outdir=~/training-runs --cfg=stylegan3-r --data="T:\\pro\\tfrecords" \
    --gpus=1 --batch=84 --batch-gpu=2 --gamma=10 --mirror=1 --kimg=5000 --snap=5 --mbstd-group=2
# Out:
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 65536,
#     "channel_max": 1024,
#     "magnitude_ema_beta": 0.9970930153280337,
#     "conv_kernel": 1,
#     "use_radial_filters": true
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 2
#     },
#     "channel_base": 32768,
#     "channel_max": 512
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.0025
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.002
#   },
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import os

# Get the system's PATH
path = os.environ['PATH']

# Print the PATH, splitting it into separate lines for readability
print(path.replace(';', '\n'))
# Out:
# c:\Users\tarun\anaconda3
# C:\Users\tarun\anaconda3
# C:\Users\tarun\anaconda3\Library\mingw-w64\bin
# C:\Users\tarun\anaconda3\Library\usr\bin
# C:\Users\tarun\anaconda3\Library\bin
# C:\Users\tarun\anaconda3\Scripts
# C:\Users\tarun\anaconda3\bin
# C:\Users\tarun\anaconda3\condabin
# C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1\bin
# C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1\libnvvp
# .
# .
# C:\Windows\system32
# C:\Windows
# C:\Windows\System32\Wbem
# C:\Windows\System32\WindowsPowerShell\v1.0
# C:\Windows\System32\OpenSSH
# C:\Program Files\dotnet
# C:\Program Files (x86)\NVIDIA Corporation\PhysX\Common
# C:\Program Files\NVIDIA Corporation\NVIDIA NvDLISR
# C:\Program Files\nodejs
# C:\Program Files\CMake\bin
# C:\Program Files (x86)\Windows Kits\10\Windows Performance Toolkit
# C:\Program Files (x86)\Microsoft Visual Studio\2022\Community\VC\Auxiliary\Build\vcvars64.bat
# C:\MinGW\mingw32\bin
# C:\Program Files\Git\cmd
# ...

# %%
import os

# Add the directory to the PATH
os.environ['PATH'] = 'path_to_directory;' + os.environ['PATH']
